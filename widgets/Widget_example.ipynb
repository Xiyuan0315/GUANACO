# %%
import scanpy as sc
adata = sc.read_h5ad('/Users/xiyuanzhang/Downloads/GUANACO_xy/data/PBMC_int.h5ad')

# %%
#1.1 Embedding, continous

# %%
import guanaco.widget as gw

# %%
fw = gw.embedding_continuous_widget(adata, 'X_pca', gene='TNF')

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'customdata': array([   0,    1,    2, ..., 8674, 8675, 8676], shape=(8677,)),
#               'hoverinfo': 'skip',
#               'marker': {'cmax': np.float32(38.826572),
#                          'cmin': np.float32(0.0),
#                          'color': array([0., 0., 0., ..., 0., 0., 0.], shape=(8677,), dtype=float32),
#                          'colorbar': {'len': 0.8, 'title': {'text': 'TNF'}},
#                          'colorscale': [[0.0, '#440154'], [0.1111111111111111,
#                                         '#482878'], [0.2222222222222222,
#                                         '#3e4989'], [0.3333333333333333,
#                                         '#31688e'], [0.4444444444444444,
#                                         '#26828e'], [0.5555555555555556,
#                                         '#1f9e89'], [0.6666666666666666,
#                                         '#35b779'], [0.7777777777777778,
# ...

# %%
#1.2 Embedding, categorical
fw = gw.embedding_categorical_widget(adata,'X_pca',color= 'Cluster')

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'marker': {'color': 'lightgrey', 'opacity': 0.3, 'size': 5},
#               'mode': 'markers',
#               'name': 'Background',
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': 'f84e583d-9197-4a37-9eb9-9fc84f730721',
#               'visible': True,
#               'x': array([-0.09707481, -0.36660767, -0.28563523, ...,  0.8329097 ,  1.0952055 ,
#                            1.3353504 ], shape=(8677,), dtype=float32),
#               'y': array([-1.5960299 ,  0.55266905,  1.4977098 , ..., -7.022947  , -5.995625  ,
#                           -5.6284776 ], shape=(8677,), dtype=float32)},
#              {'customdata': array(['Bcells', 'Bcells', 'Bcells', ..., 'Bcells', 'Bcells', 'Bcells'],
#                                   shape=(578,), dtype=object),
#               'hoverinfo': 'skip',
#               'legendgroup': 'Bcells',
# ...

# %%
from guanaco.widget import embedding_coexpression_widget

# %%
#1.3 Embedding, co-expression
# threshoulds are optional
fw = gw.embedding_coexpression_widget(adata,'X_umap',gene1 = 'CD8A',gene2 = 'CD96',threshold1 = 0.5,threshold2 = 0.5)

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'customdata': array([   2,    4,    5, ..., 8674, 8675, 8676], shape=(5003,)),
#               'hoverinfo': 'skip',
#               'marker': {'color': '#E8E8E8', 'opacity': 1.0, 'size': 5},
#               'mode': 'markers',
#               'name': 'Neither',
#               'selected': {'marker': {'opacity': 1}},
#               'showlegend': False,
#               'type': 'scattergl',
#               'uid': '426d29a7-5046-4b4d-bbc2-df885dc59bc5',
#               'unselected': {'marker': {'opacity': 0.2}},
#               'x': array([-2.6643248 , 11.390784  ,  0.74067676, ...,  4.879983  ,  4.8134575 ,
#                            4.6278358 ], shape=(5003,), dtype=float32),
#               'y': array([ 4.494578 ,  7.8788595, -1.3129439, ...,  5.561369 ,  5.3697248,
#                            5.3973947], shape=(5003,), dtype=float32)},
#              {'customdata': array([   0,    3,   70, ..., 8233, 8547, 8633], shape=(303,)),
# ...

# %%
#2.1 Heatmap
import guanaco.widget as gw

# %%
fw = gw.heatmap_widget(adata,genes = ['CD8A','CD96'],groupby1= 'Cluster',groupby2 = 'Dataset')

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'colorbar': {'len': 0.4, 'title': {'text': 'Expression'}, 'y': 1, 'yanchor': 'top'},
#               'colorscale': [[0.0, '#440154'], [0.1111111111111111, '#482878'],
#                              [0.2222222222222222, '#3e4989'], [0.3333333333333333,
#                              '#31688e'], [0.4444444444444444, '#26828e'],
#                              [0.5555555555555556, '#1f9e89'], [0.6666666666666666,
#                              '#35b779'], [0.7777777777777778, '#6ece58'],
#                              [0.8888888888888888, '#b5de2b'], [1.0, '#fde725']],
#               'hoverinfo': 'skip',
#               'type': 'heatmap',
#               'uid': '8f2aaa68-77f8-46e6-8570-cb82560b3b4e',
#               'x': [0, 1, 2, ..., 8674, 8675, 8676],
#               'xaxis': 'x',
#               'y': [0, 1],
#               'yaxis': 'y',
#               'z': array([[ 0.       ,  0.       ,  0.       , ...,  0.       ,  0.       ,
# ...

# %%
fw = gw.heatmap_widget(adata,genes = ['CD8A','CD96'],groupby1= 'Cluster',z_score=True)

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'colorbar': {'len': 0.5, 'title': {'text': 'Expression(z-score)'}, 'y': 1, 'yanchor': 'top'},
#               'colorscale': [[0.0, '#440154'], [0.1111111111111111, '#482878'],
#                              [0.2222222222222222, '#3e4989'], [0.3333333333333333,
#                              '#31688e'], [0.4444444444444444, '#26828e'],
#                              [0.5555555555555556, '#1f9e89'], [0.6666666666666666,
#                              '#35b779'], [0.7777777777777778, '#6ece58'],
#                              [0.8888888888888888, '#b5de2b'], [1.0, '#fde725']],
#               'hoverinfo': 'skip',
#               'type': 'heatmap',
#               'uid': 'e4cbd3e4-9f91-4b7f-a994-83eeb0f0d08f',
#               'x': [0, 1, 2, ..., 8674, 8675, 8676],
#               'xaxis': 'x',
#               'y': [0, 1],
#               'yaxis': 'y',
#               'z': array([[-0.30867746, -0.30867746, -0.30867746, ..., -0.30867746, -0.30867746,
# ...

# %%
#3.1 Violin1
fw = gw.violin1_widget(
    adata,
    genes = ['CD8A'],
    # labels = '',
    groupby = 'Cluster',
    transformation = 'log'
)

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'box': {'visible': False},
#               'fillcolor': '#E69F00',
#               'hoverinfo': 'y',
#               'hoveron': 'violins',
#               'jitter': 0.05,
#               'line': {'color': 'DarkSlateGrey'},
#               'marker': {'size': 2},
#               'meanline': {'visible': True},
#               'name': 'Bcells',
#               'points': False,
#               'scalegroup': 'Bcells',
#               'scalemode': 'width',
#               'showlegend': True,
#               'spanmode': 'hard',
#               'type': 'violin',
#               'uid': '7df1a9da-742b-4610-a13f-a362db001011',
#               'width': 0.8,
#               'x': array(['Bcells', 'Bcells', 'Bcells', ..., 'Bcells', 'Bcells', 'Bcells'],
#                          shape=(578,), dtype=object),
#               'xaxis': 'x',
#               'y': array([0., 0., 0., ..., 0., 0., 0.], shape=(578,), dtype=float32),
#               'yaxis': 'y'},
# ...

# %%
# 3.2 Violin2
fw = gw.violin2_widget(adata, 'CD96', 'Cluster', 'Dataset', mode = 'mode1')

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'box': {'visible': True},
#               'fillcolor': '#E69F00',
#               'hoveron': 'violins',
#               'jitter': 0.05,
#               'line': {'color': 'DarkSlateGrey'},
#               'marker': {'size': 1.5},
#               'meanline': {'visible': True},
#               'name': 'Bcells',
#               'points': 'all',
#               'showlegend': False,
#               'spanmode': 'hard',
#               'type': 'violin',
#               'uid': '35294d71-090e-4b3e-8f20-ee81952ddce8',
#               'width': 0.8,
#               'x': [Bcells, Bcells, Bcells, ..., Bcells, Bcells, Bcells],
#               'y': array([ 0.     ,  0.     , 13.25381, ...,  0.     ,  0.     ,  0.     ],
#                          shape=(578,), dtype=float32)},
#              {'box': {'visible': True},
#               'fillcolor': '#56B4E9',
#               'hoveron': 'violins',
#               'jitter': 0.05,
# ...

# %%
# 4.1 dot plot
fw = gw.dotmatrix_widget(
    adata,
    ['CD8A','CD96','TNF'],
    groupby = 'Cluster',
    cluster  = 'both'
)

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'customdata': array([[0.20558725, 0.03118908],
#                                    [0.12227896, 0.03943662],
#                                    [0.05916351, 0.01730104],
#                                    [0.42486164, 0.15079365],
#                                    [0.30654421, 0.05679176],
#                                    [0.20585556, 0.03655914],
#                                    [0.0849859 , 0.04072398],
#                                    [3.51116991, 0.55555556],
#                                    [0.03186977, 0.01086519],
#                                    [0.04462614, 0.01384083],
#                                    [0.02916348, 0.01322751],
#                                    [0.16381368, 0.03819329],
#                                    [0.42717382, 0.07956989],
#                                    [0.01991365, 0.01357466],
#                                    [6.21520948, 0.70110461],
# ...

# %%
# 4.2 matrix plot
fw = gw.dotmatrix_widget(
    adata,
    ['CD8A','CD96','TNF'],
    groupby = 'Cluster',
    cluster  = 'both',
    plot_type='matrixplot'
)

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'colorbar': {'len': 0.6,
#                            'tickfont': {'color': 'DarkSlateGrey', 'size': 10},
#                            'title': {'text': 'Mean Expression'},
#                            'x': 0.98,
#                            'y': 0.5,
#                            'yanchor': 'middle'},
#               'colorscale': [[0.0, '#440154'], [0.1111111111111111, '#482878'],
#                              [0.2222222222222222, '#3e4989'], [0.3333333333333333,
#                              '#31688e'], [0.4444444444444444, '#26828e'],
#                              [0.5555555555555556, '#1f9e89'], [0.6666666666666666,
#                              '#35b779'], [0.7777777777777778, '#6ece58'],
#                              [0.8888888888888888, '#b5de2b'], [1.0, '#fde725']],
#               'hovertemplate': '%{y}<br>%{x}<br>Expression: %{z:.2f}<extra></extra>',
#               'type': 'heatmap',
# ...

# %%
# 5 stacked bar
fw = gw.stacked_bar_widget(
    adata,
    x_meta = 'Dataset',
    y_meta = 'Cluster',
    norm= 'count',
)
# Out:
# /Users/xiyuanzhang/Documents/GUANACO/guanaco-viz/guanaco/pages/matrix/cellplotly/stacked_bar.py:62: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'Cluster=Bcells<br>Dataset=%{x}<br>Cell Count=%{y}<extra></extra>',
#               'legendgroup': 'Bcells',
#               'marker': {'color': '#E69F00', 'pattern': {'shape': ''}},
#               'name': 'Bcells',
#               'offsetgroup': 'Bcells',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'type': 'bar',
#               'uid': 'bb71cd28-91a0-4ca0-b2fd-720d7660a069',
#               'x': array(['10X3k', '10X10k'], dtype=object),
#               'xaxis': 'x',
#               'y': array([181, 397]),
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
#               'hovertemplate': 'Cluster=CD4+Tcells<br>Dataset=%{x}<br>Cell Count=%{y}<extra></extra>',
#               'legendgroup': 'CD4+Tcells',
#               'marker': {'color': '#56B4E9', 'pattern': {'shape': ''}},
# ...

# %%
adata = sc.read_h5ad('/Users/xiyuanzhang/Downloads/GUANACO_xy/data/paul15.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2730 × 999
#     obs: 'paul15_clusters', 'n_counts_all', 'leiden', 'dpt_pseudotime', 'cell_type'
#     var: 'n_counts', 'mean', 'std'
#     uns: 'diffmap_evals', 'draw_graph', 'iroot', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'paul15_clusters_colors', 'pca'
#     obsm: 'X_diffmap', 'X_draw_graph_fr', 'X_pca'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
fw = gw. pseudotime_widget(
    adata,
    genes = ['Gata1','Gata2'],
    pseudotime_key='dpt_pseudotime',
    groupby = 'cell_type',
    min_expr=2
)

# %%
fw
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'legendgroup': 'Baso',
#               'marker': {'color': '#636EFA', 'opacity': 0.6, 'size': 3},
#               'mode': 'markers',
#               'name': 'Baso',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3f393ead-2c8f-4356-b7cc-3f28fb99bd6e',
#               'x': array([0.01416879, 0.02123805, 0.0229289 , 0.02940043, 0.04143111, 0.04558016,
#                           0.04874565, 0.04915649, 0.05295826, 0.05949611, 0.09209819, 0.10382192,
#                           0.12715642, 0.13471943, 0.1360382 , 0.14820123, 0.14978717, 0.15003432,
#                           0.15188184, 0.15238245, 0.15517236, 0.15832372, 0.15956113, 0.16247265,
#                           0.17463502, 0.17939532, 0.18122004, 0.18303476, 0.18449177, 0.1950864 ,
#                           0.20378783, 0.21557309, 0.28938776], dtype=float32),
#               'xaxis': 'x',
# ...
